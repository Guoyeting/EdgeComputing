# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
def read_raw_weeplace(path):
    raw_data = pd.read_csv(path)
    return raw_data

# %%
raw_path = 'data/raw/weeplace_checkins.csv'
raw_data = read_raw_weeplace(raw_path)

# %%
raw_data.loc[:,'datetime'] = pd.to_datetime(raw_data.loc[:,'datetime'], format='%Y-%m-%dT%H:%M:%S')

# %%
raw_data.loc[:, 'date'] = raw_data.loc[:, 'datetime'].map(lambda x : x.date())
raw_data.loc[:, 'time'] = raw_data.loc[:, 'datetime'].map(lambda x : x.time())

# %%
filter_data = raw_data.groupby(['userid', 'date']).filter(lambda x : len(x) > 5)
groups = filter_data.groupby(['userid', 'date'])
filter_data['group_id'] = groups.grouper.label_info
# Out:
# /media/raid6/uqqwan18/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
filter_data = filter_data.sort_values(by = ['userid', 'date', 'time'])

# %%
filter_data.loc[:,'POI'] = filter_data.loc[:,'lat'] + filter_data.loc[:,'lon']

# %%
unique_POIs = filter_data['userid'].unique()
POI_dict = {unique_POIs[i]: i for i in range(len(unique_POIs))}
filter_data.loc[:,'userid'] = filter_data.loc[:,'userid'].apply(lambda x: POI_dict[x])

# %%
unique_POIs = filter_data['POI'].unique()
POI_dict = {unique_POIs[i]: i for i in range(len(unique_POIs))}

# %%
filter_data.loc[:,'POI_ID'] = filter_data.loc[:,'POI'].apply(lambda x: POI_dict[x])

# %%
start_i = -1
start_labels = []
for idx, row in filter_data.iterrows():
    if row['group_id'] != start_i:
        start_labels.append(idx)
        start_i += 1

# %%
filter_data['dtime'] = filter_data['datetime'].diff(periods=1).fillna(0).dt.floor('T').dt.total_seconds().div(60).astype(int)
# Out:
# /media/raid6/uqqwan18/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Passing integers to fillna is deprecated, will raise a TypeError in a future version.  To retain the old behavior, pass pd.Timedelta(seconds=n) instead.
#   """Entry point for launching an IPython kernel.

# %%
filter_data.loc[start_labels, 'dtime'] = 0
filter_data['tlower'] = (filter_data['dtime'] / 10).astype(int) * 10
filter_data['tupper'] = filter_data['tlower'] + 10

# %%
shifted_lats = filter_data['lat'].shift(1).fillna(0)
shifted_lons = filter_data['lon'].shift(1).fillna(0)

# %%
filter_data['ddist'] = ((filter_data['lat'] - shifted_lats).apply(lambda x: x*x) + (filter_data['lon'] - shifted_lons).apply(lambda x: x*x)).apply(lambda x: np.sqrt(x))

# %%
filter_data['ddist'] = np.ceil(filter_data['ddist'] * 100000 / 100).astype(int)

# %%
filter_data['ddist'] = filter_data['ddist'].map(lambda x: 2000 if x > 2000 else x)

# %%
filter_data.loc[start_labels, 'ddist'] = 0
filter_data['dlower'] = (filter_data['ddist'] / 10).astype(int) * 10
filter_data['dupper'] = filter_data['dlower'] + 10

# %%
dtime_set = set(filter_data['tupper'].unique()).union(set(filter_data['tlower'].unique()))
ddist_set = set(filter_data['dupper'].unique()).union(set(filter_data['dlower'].unique()))
dtime_dict = {value: key for key, value in enumerate(dtime_set)}
ddist_dict = {value: key for key, value in enumerate(ddist_set)}

# %%
filter_data.loc[:,'tupper_id'] = filter_data.loc[:,'tupper'].apply(lambda x: dtime_dict[x])
filter_data.loc[:,'tlower_id'] = filter_data.loc[:,'tlower'].apply(lambda x: dtime_dict[x])
filter_data.loc[:,'dupper_id'] = filter_data.loc[:,'dupper'].apply(lambda x: ddist_dict[x])
filter_data.loc[:,'dlower_id'] = filter_data.loc[:,'dlower'].apply(lambda x: ddist_dict[x])

# %%
max_lens = 0
user_visits = dict()
for gname, group in filter_data.groupby('userid'):
    if max_lens < group.shape[0]:
        max_lens = group.shape[0]
    user_visits[gname] = group['POI_ID']

# %%
all_pois = set(filter_data['POI_ID'].unique())
all_pois_l = list(all_pois)
for col_name in ['neg1', 'neg2']:
    negs = np.random.choice(all_pois_l, [filter_data['userid'].nunique() * 2, max_lens])
    user_negs = []
    i = 0
    for user in filter_data['userid'].unique():
        user_len = user_visits[user].shape[0]
        cand_negs = negs[i, :user_len]
        if len(set(cand_negs).intersection(set(user_visits[user]))) != 0:
            cand_negs = np.random.choice(list(all_pois.difference(set(user_visits[user]))), user_len)
        user_negs.extend(cand_negs)
        i += 1
    filter_data[col_name] = np.array(user_negs)

# %%
group_sizes = dict()
for gid, gsize in filter_data.groupby('group_id').grouper.size().iteritems():
    group_sizes[gid] = gsize

# %%
filter_data['group_size'] = filter_data['group_id'].map(lambda x: group_sizes[x])

# %%
filter_data.to_csv('data/weeplace_filter.csv', index = False)

# %%
sized_dataset = filter_data[filter_data['group_size'] == 6]

# %%
for gid, group in sized_dataset.groupby('group_id'):
    print(group.loc[:, ['POI_ID', 'dtime', 'tupper', 'tlower', 'tupper_id', 'tlower_id', 'ddist', 'dlower', 'dupper', 'dlower_id', 'dupper_id', 'neg1', 'neg2']].values)
    break
# Out:
# [[     0      0     10      0      3      0      0      0     10      0
#        2 180890 373368]
#  [     1      7     10      0      3      0      1      0     10      0
#        2 157733 511427]
#  [     2      5     10      0      3      0      2      0     10      0
#        2 221976  11444]
#  [     3    460    470    460    135    133      2      0     10      0
#        2 408481  77983]
#  [     4     89     90     80     27     24      5      0     10      0
#        2 132905 580291]
#  [     5     37     40     30     12      9     66     60     70     12
#       14 401932 500579]]

# %%
sized_dataset.groupby('group_id').ngroups
# Out:
# 96353

# %%
filter_data.columns
# Out:
# Index(['userid', 'placeid', 'datetime', 'lat', 'lon', 'city', 'category',
#        'date', 'time', 'group_id', 'POI', 'POI_ID', 'dtime', 'tlower',
#        'tupper', 'ddist', 'dlower', 'dupper', 'tupper_id', 'tlower_id',
#        'dupper_id', 'dlower_id', 'neg1', 'neg2', 'group_size'],
#       dtype='object')

# %%
filter_data['group_id'].nunique()
# Out:
# 338492

# %%
filter_data.shape[0]
# Out:
# 3160983

# %%
filter_data
# Out:
#          userid                                            placeid  \
# 7247182       0                                                NaN
# 7247181       0                                                NaN
# 7247180       0                                                  1
# 7247179       0                                                NaN
# 7247178       0                                         jr-1-tokyo
# 7247177       0                                                NaN
# 7247172       0                                                NaN
# 7247171       0                                                NaN
# 7247170       0                                                NaN
# 7247169       0                                                NaN
# 7247168       0                                                NaN
# 7247167       0                                              akiba
# 7247166       0                                              akiba
# 7247165       0                                                  4
# 4803217                         Travel:Train Station  2010-06-29  07:27:49
# 4803216        Home / Work / Other:Gym / Fitness:Gym  2010-06-29  07:50:24
# 4803155                               Travel:Airport  2010-10-10  09:32:09
# 4803156                                          NaN  2010-10-10  09:40:38
# 4803157                               Travel:Airport  2010-10-10  11:50:35
# 4803158                               Shops:Services  2010-10-10  12:39:31
# 4803159                    Shops:Apparel:Accessories  2010-10-10  12:51:25
# 4803160                     Travel:Highway / Traffic  2010-10-10  21:16:15
# 4803177                               Food:Fast Food  2010-10-20  03:37:25
# 4803178                             Shops:Automotive  2010-10-20  04:06:41
# 4803179  Home / Work / Other:Medical:Doctor's Office  2010-10-20  04:29:15
# 4803180        Home / Work / Other:Gym / Fitness:Gym  2010-10-20  18:44:26
# 4803181     Shops:Food & Drink:Grocery / Supermarket  2010-10-20  20:39:54
# 4803182                     Travel:Highway / Traffic  2010-10-20  23:20:31
#
#          group_id  ...  ddist  dlower  dupper  tupper_id  tlower_id  \
# 7247182         0  ...      0       0      10          3          0
# 7247181         0  ...      1       0      10          3          0
# 7247180         0  ...      2       0      10          3          0
# 7247179         0  ...      2       0      10        135        133
# 7247178         0  ...      5       0      10         27         24
# 7247177         0  ...     66      60      70         12          9
# 7247172         1  ...      0       0      10          3          0
# 7247171         1  ...     60      60      70         15         12
# 7247170         1  ...     41      40      50         48         45
# 7247169         1  ...      1       0      10         36         33
# 7247168         1  ...      3       0      10         12          9
# 7247167         1  ...     58      50      60         27         24
# 7247166         1  ...      1       0      10         12          9
# 7247165         1  ...     73      70      80         36         33
# 7247164         1  ...      5       0      10          6          3
# 7247163         1  ...      0       0      10         39         36
# 7247162         1  ...      0       0      10         33         30
# 7247161         2  ...      0       0      10          3          0
# 7247160         2  ...    117     110     120         15         12
# 7247159         2  ...      3       0      10          3          0
# 7247158         2  ...      3       0      10         15         12
# 7247157         2  ...     90      90     100         33         30
# 7247156         2  ...     24      20      30         63         60
# 7247155         2  ...      2       0      10          3          0
# 7247154         2  ...      2       0      10          6          3
# 7247153         2  ...      2       0      10          3          0
# 7247152         2  ...      3       0      10          6          3
# 7247151         2  ...      2       0      10          3          0
# 7247150         2  ...      2       0      10          3          0
# 7247149         2  ...      2       0      10          3          0
# ...           ...  ...    ...     ...     ...        ...        ...
# 4803369    338487  ...     30      30      40          3          0
# 4803368    338487  ...     66      60      70         42         39
# 4803367    338487  ...     60      60      70         42         39
# 4803366    338487  ...    120     120     130         30         27
# 4803365    338487  ...    155     150     160         45         42
# 4803238    338488  ...      0       0      10          3          0
# 4803237    338488  ...      1       0      10          3          0
# 4803236    338488  ...     56      50      60         12          9
# 4803235    338488  ...     11      10      20         15         12
# 4803234    338488  ...      2       0      10         21         18
# 4803233    338488  ...     63      60      70         12          9
# 4803222    338489  ...      0       0      10          3          0
# 4803221    338489  ...      3       0      10          3          0
# 4803220    338489  ...      1       0      10          6          3
# 4803219    338489  ...      4       0      10          6          3
# 4803218    338489  ...      3       0      10         66         63
# 4803217    338489  ...    103     100     110         15         12
# 4803216    338489  ...     47      40      50          9          6
# 4803155    338490  ...      0       0      10          3          0
# 4803156    338490  ...     10      10      20          3          0
# 4803157    338490  ...   2000    2000    2010         39         36
# 4803158    338490  ...     97      90     100         15         12
# 4803159    338490  ...     69      60      70          6          3
# 4803160    338490  ...     52      50      60        143        141
# 4803177    338491  ...      0       0      10          3          0
# 4803178    338491  ...     57      50      60          9          6
# 4803179    338491  ...     46      40      50          9          6
# 4803180    338491  ...     31      30      40        104        101
# 4803181    338491  ...      1       0      10         36         33
# 4803182    338491  ...     35      30      40         51         48
#
#          dupper_id  dlower_id    neg1    neg2  group_size
# 7247182          2          0  180890  373368           6
# 7247181          2          0  157733  511427           6
# 7247180          2          0  221976   11444           6
# 7247179          2          0  408481   77983           6
# 7247178          2          0  132905  580291           6
# 7247177         14         12  401932  500579           6
# 7247172          2          0  245571   49130          11
# 7247171         14         12  285554  484562          11
# 7247170         10          8  518406  387947          11
# 7247169          2          0  366080  206405          11
# 7247168          2          0  567753   72837          11
# 7247167         12         10  429290  291202          11
# 7247166          2          0   14833  493959          11
# 7247165         16         14  204825  364410          11
# 7247164          2          0  622621  440545          11
# 7247163          2          0  479530  356557          11
# 7247162          2          0  618213  568097          11
# 7247161          2          0  547386  531409          19
# 7247160         24         22   83326  207733          19
# 7247159          2          0  252177  185359          19
# 7247158          2          0   11733  366401          19
# 7247157         20         18  218420  412112          19
# 7247156          6          4  335752  403435          19
# 7247155          2          0  493259   64268          19
# 7247154          2          0  455424  427929          19
# 7247153          2          0  181856  188261          19
# 7247152          2          0  318346  198590          19
# 7247151          2          0  505537  541645          19
# 7247150          2          0  291147  113125          19
# 7247149          2          0  323917  526712          19
# ...            ...        ...     ...     ...         ...
# 4803369          8          6  342563  199086           6
# 4803368         14         12  565858  625211           6
# 4803367         14         12  610535  530762           6
# 4803366         26         24   13273  391215           6
# 4803365         32         30  400384  473719           6
# 4803238          2          0  153115   92577           6
# 4803237          2          0  300154  615015           6
# 4803236         12         10  104199  558763           6
# 4803235          4          2  334997  139554           6
# 4803234          2          0  216008  340841           6
# 4803233         14         12   77133  275747           6
# 4803222          2          0  391837  488301           7
# 4803221          2          0  162909   31424           7
# 4803220          2          0  468473  283028           7
# 4803219          2          0  487996  430726           7
# 4803218          2          0  315141  223867           7
# 4803217         22         20  378530   49709           7
# 4803216         10          8   78231  184749           7
# 4803155          2          0  532008  203052           6
# 4803156          4          2  186000    5455           6
# 4803157        197        195  618587  377836           6
# 4803158         20         18  397297  410835           6
# 4803159         14         12  464268  380378           6
# 4803160         12         10   33513   48628           6
# 4803177          2          0  217906  368192           6
# 4803178         12         10  386243  345752           6
# 4803179         10          8  223988  200155           6
# 4803180          8          6   29656  628186           6
# 4803181          2          0  520261  326122           6
# 4803182          8          6   81647  318522           6
#
# [3160983 rows x 25 columns]

# %%
poi_cat = dict()
for poi, cat  in zip(filter_data['POI_ID'], filter_data['category']):
    poi_cat[poi] = cat

# %%
import pickle
pickle.dump(poi_cat, open('data/cat_dict', 'wb' ))
